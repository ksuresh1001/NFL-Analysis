# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv('NFL.csv')

# %%
df
# Out:
#     Wins  Point Differential  Total Rank                  Team  Pts/Game  \
# 0     12                 144           1    Kansas City Chiefs      35.3
# 1     13                 143           2      Los Angeles Rams      32.9
# 2      5                 -68           3  Tampa Bay Buccaneers      24.8
# 3      9                  68           4   Pittsburgh Steelers      26.8
# 4     11                 111           5  New England Patriots      27.2
# 5      7                  -9           6       Atlanta Falcons      25.9
# 6     10                  89           7    Indianapolis Colts      27.1
# 7     13                 151           8    New Orleans Saints      31.5
# 8     10                 102           9      Baltimore Ravens      24.3
# 9      7                  -6          10     Carolina Panthers      23.5
# 10    12                  99          11  Los Angeles Chargers      26.8
# 11     6                 -24          12     Green Bay Packers      23.5
# ...

# %%
#https://www.kaggle.com/dansbecker/your-first-machine-learning-model
y=df.Wins

# %%
corr=['Point Differential', 'Pts/Game', 'Total yds/play', '3rd downs made', '4th downs made', 'Penalties', 'Pass Yards', 'Rush Yds', 'Int', 'Defense TotPts', 'Pass Yds Against', 'Rush Yds Against']

# %%
x=df[corr]

# %%
x.describe()
# Out:
#        Point Differential   Pts/Game  Total yds/play  3rd downs made  \
# count           32.000000  32.000000       32.000000       32.000000
# mean             0.000000  23.346875        5.590625       78.875000
# std             96.279499   4.759234        0.537233       10.859068
# min           -200.000000  14.100000        4.300000       56.000000
# 25%            -72.750000  20.500000        5.300000       73.000000
# 50%             -7.500000  23.050000        5.600000       77.000000
# 75%             86.750000  26.425000        5.900000       84.500000
# max            151.000000  35.300000        6.800000      104.000000
#
#        4th downs made   Penalties   Pass Yards     Rush Yds        Int  \
# count       32.000000   32.000000    32.000000    32.000000  32.000000
# mean         9.375000  107.656250  3804.281250  1831.156250  13.093750
# std          2.485441   11.558015   666.602277   274.926044   4.788153
# ...

# %%
bigboi = DecisionTreeRegressor(random_state=1)

# %%
bigboi.fit(x, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=1, splitter='best')

# %%
x
# Out:
#     Point Differential  Pts/Game  Total yds/play  3rd downs made  \
# 0                  144      35.3             6.8              83
# 1                  143      32.9             6.4              86
# 2                  -68      24.8             6.3              86
# 3                   68      26.8             6.1              88
# 4                  111      27.2             5.9              82
# 5                   -9      25.9             6.2              92
# 6                   89      27.1             5.8             104
# 7                  151      31.5             6.0              82
# 8                  102      24.3             5.3             104
# 9                   -6      23.5             5.9              77
# 10                  99      26.8             6.3              70
# 11                 -24      23.5             5.8              75
# 12                 -33      22.4             5.8              73
# ...

# %%
bigboi.predict(x)
# Out:
# array([12., 13.,  5.,  9., 11.,  7., 10., 13., 10.,  7., 12.,  6.,  7.,
#         9., 11.,  4.,  5., 10.,  6.,  8., 12., 10.,  4.,  6.,  9.,  6.,
#         5.,  7.,  4.,  6.,  7.,  3.])

# %%
pred = bigboi.predict(x)
mean_absolute_error(y, pred)
# Out:
# 0.0

# %%
#https://www.kaggle.com/dansbecker/model-validation
train_X, val_X, train_y, val_y = train_test_split(x, y, random_state = 0)

# %%
biggerboi = DecisionTreeRegressor()
biggerboi.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
y_pred = biggerboi.predict(val_X)
# Out:
# 1.875

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(val_y, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(val_y, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(val_y, y_pred)))
# Out:
# Mean Absolute Error: 1.875
# Mean Squared Error: 3.875
# Root Mean Squared Error: 1.9685019685029528

# %%
df_val = pd.DataFrame({'Actual': val_y, 'Predicted': y_pred})  
print(df_val)
# Out:
#     Actual  Predicted
# 11       6        7.0
# 22       4        7.0
# 10      12       10.0
# 2        5        7.0
# 16       5        7.0
# 14      11       10.0
# 28       4        6.0
# 26       5        7.0
